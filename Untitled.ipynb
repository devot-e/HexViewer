# %%
import subprocess
import os
import shutil
import signal
import curses

# %%
fileN="HexView.py"
file_checksum=subprocess.getoutput(f'sha256sum {fileN}')

# %%
file_checksum.split()
# Out:
# ['8b902e39669caf483faffa7be619d46ab8ffc181312720ff25ef85aa5b5f0583',
#  'HexView.py']

# %%
a=shutil.get_terminal_size()

# %%
a.columns
a.lines
# Out:
# 24

# %%
w = curses.initscr()
a=w.getkey()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[63], line 2
#       1 w = curses.initscr()
# ----> 2 a=w.getkey()
#       3 type(a)
#
# error: no input
